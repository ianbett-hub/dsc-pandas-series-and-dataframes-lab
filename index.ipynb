# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands-on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# - Use the `.map()` and `.apply()` methods to apply a function to a pandas Series or DataFrame
# - Perform operations to change the structure of pandas DataFrames
# - Change the index of a pandas DataFrame
# - Change data types of columns in pandas DataFrames
#
# ## Let's get started
#
# Import the file `'turnstile_180901.txt'`.

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the file 'turnstile_180901.txt'
df = pd.read_csv('turnstile_180901.txt')

# Print the number of rows ans columns in df
print(df.shape)

# Print the first five rows of df
df.head()
# Out:
# (197625, 11)
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Rename all the columns to lower case:

# %%
# We can check and see what the columns look like with this code:
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
# Rename all the columns to lower case
df.rename(columns=str.lower, inplace=True)

# %%
# Now let's check and make sure that worked
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               '],
#       dtype='object')

# %% [markdown]
# Change the index to `'linename'`:

# %%
# Change the index to 'linename'
df = df.set_index('linename')

# %% [markdown]
# Reset the index:

# %%
# Reset the index
# Reset the index and keep the current index as a column
df = df.reset_index()

df
# Out:
#        linename  level_0   index    c/a  unit       scp        station  \
# 0       NQR456W        0       0   A002  R051  02-00-00          59 ST
# 1       NQR456W        1       1   A002  R051  02-00-00          59 ST
# 2       NQR456W        2       2   A002  R051  02-00-00          59 ST
# 3       NQR456W        3       3   A002  R051  02-00-00          59 ST
# 4       NQR456W        4       4   A002  R051  02-00-00          59 ST
# ...         ...      ...     ...    ...   ...       ...            ...
# 197620        R   197620  197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT
# 197621        R   197621  197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT
# 197622        R   197622  197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT
# 197623        R   197623  197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT
# 197624        R   197624  197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT
#
#        division        date      time     desc  entries  \
# 0           BMT  08/25/2018  00:00:00  REGULAR  6736067
# 1           BMT  08/25/2018  04:00:00  REGULAR  6736087
# 2           BMT  08/25/2018  08:00:00  REGULAR  6736105
# 3           BMT  08/25/2018  12:00:00  REGULAR  6736180
# 4           BMT  08/25/2018  16:00:00  REGULAR  6736349
# ...         ...         ...       ...      ...      ...
# 197620      RIT  08/31/2018  05:00:00  REGULAR     5554
# 197621      RIT  08/31/2018  09:00:00  REGULAR     5554
# 197622      RIT  08/31/2018  13:00:00  REGULAR     5554
# 197623      RIT  08/31/2018  17:00:00  REGULAR     5554
# 197624      RIT  08/31/2018  21:00:00  REGULAR     5554
#
#         exits
# 0                                                 2283184
# 1                                                 2283188
# 2                                                 2283229
# 3                                                 2283314
# 4                                                 2283384
# ...                                                   ...
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
# [197625 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['linename', 'level_0', 'index', 'c/a', 'unit', 'scp', 'station',
#        'division', 'date', 'time', 'desc', 'entries',
#        'exits                                                               '],
#       dtype='object')

# %%
df = df.drop(['level_0', 'index'], axis=1)
df
# Out:
#        linename    c/a  unit       scp        station division        date  \
# 0       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 1       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 2       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 3       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 4       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# ...         ...    ...   ...       ...            ...      ...         ...
# 197620        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# 197621        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# 197622        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# 197623        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
# 197624        R  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018
#
#             time     desc  entries  \
# 0       00:00:00  REGULAR  6736067
# 1       04:00:00  REGULAR  6736087
# 2       08:00:00  REGULAR  6736105
# 3       12:00:00  REGULAR  6736180
# 4       16:00:00  REGULAR  6736349
# ...          ...      ...      ...
# 197620  05:00:00  REGULAR     5554
# 197621  09:00:00  REGULAR     5554
# 197622  13:00:00  REGULAR     5554
# 197623  17:00:00  REGULAR     5554
# 197624  21:00:00  REGULAR     5554
#
#         exits
# 0                                                 2283184
# 1                                                 2283188
# 2                                                 2283229
# 3                                                 2283314
# 4                                                 2283384
# ...                                                   ...
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
# [197625 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['linename', 'c/a', 'unit', 'scp', 'station', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               '],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 197625 entries, 132292 to 197624
# Data columns (total 12 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   linename                                                              197625 non-null  object
#  1   c/a                                                                   197625 non-null  object
#  2   unit                                                                  197625 non-null  object
#  3   scp                                                                   197625 non-null  object
#  4   station                                                               197625 non-null  object
#  5   division                                                              197625 non-null  object
#  6   date                                                                  197625 non-null  object
#  7   time                                                                  197625 non-null  object
#  8   desc                                                                  197625 non-null  object
#  9   entries                                                               197625 non-null  int64
#  10  exits                                                                 197625 non-null  int64
#  11  Num_Lines                                                             197625 non-null  int64
# dtypes: int64(3), object(9)
# memory usage: 19.6+ MB

# %% [markdown]
# Create another column `'Num_Lines'` that is a count of how many lines pass through a station. Then sort your DataFrame by this column in descending order.
#
# *Hint: According to the [data dictionary](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt), LINENAME represents all train lines that can be boarded at a given station. Normally lines are represented by one character. For example, LINENAME 456NQR represents trains 4, 5, 6, N, Q, and R.*

# %%
# Add a new 'num_lines' column
# Step 1: Count the unique train lines by counting characters in the 'LINENAME' column
df['Num_Lines'] = df['linename'].apply(len)

# Step 2: Sort by 'Num_Lines' in descending order
df = df.sort_values(by='Num_Lines', ascending=False)

# %% [markdown]
# Write a function to clean column names:

# %%
# Before we start cleaning, let's look at what we've got

df.columns
# Out:
# Index(['linename', 'c/a', 'unit', 'scp', 'station', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               ',
#        'Num_Lines'],
#       dtype='object')

# %%
df
# Out:
#             linename    c/a  unit       scp         station division  \
# 132292  1237ACENQRSW   R151  R033  00-00-00  TIMES SQ-42 ST      IRT
# 2686    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2673    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2674    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2675    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# ...              ...    ...   ...       ...             ...      ...
# 112565             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112564             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112563             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112562             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 197624             R  TRAM2  R469  00-05-01   RIT-ROOSEVELT      RIT
#
#               date      time     desc  entries  \
# 132292  08/30/2018  00:00:00  REGULAR  1417952
# 2686    08/29/2018  16:00:00  REGULAR  2836145
# 2673    08/27/2018  16:00:00  REGULAR  2830710
# 2674    08/27/2018  20:00:00  REGULAR  2832048
# 2675    08/28/2018  00:00:00  REGULAR  2832325
# ...            ...       ...      ...      ...
# 112565  08/27/2018  09:28:23  REGULAR    28975
# 112564  08/27/2018  05:16:23  REGULAR    28319
# 112563  08/27/2018  01:04:23  REGULAR    28318
# 112562  08/26/2018  20:52:23  REGULAR    28305
# 197624  08/31/2018  21:00:00  REGULAR     5554
#
#         exits                                                                 \
# 132292                                            3267016
# 2686                                              3311412
# 2673                                              3305818
# 2674                                              3306310
# 2675                                              3306433
# ...                                                   ...
# 112565                                              12659
# 112564                                              12541
# 112563                                              12541
# 112562                                              12531
# 197624                                                348
#
#         Num_Lines
# 132292         12
# 2686           12
# 2673           12
# 2674           12
# 2675           12
# ...           ...
# 112565          1
# 112564          1
# 112563          1
# 112562          1
# 197624          1
#
# [197625 rows x 12 columns]

# %%
# def clean(col_name):
#     # Clean the column name in any way you want to. Hint: think back to str methods 
#     cleaned = 
#     return cleaned

# %%
def clean(col_name):
    # Strip leading/trailing whitespace
    cleaned = col_name.strip()
    
    # Convert to lowercase
    cleaned = cleaned.lower()
    
    # Replace spaces with underscores
    cleaned = cleaned.replace(' ', '_')
    
    # Optionally, replace any special characters (e.g., '/')
    cleaned = cleaned.replace('/', '_')
    
    # You can add more cleaning operations as needed (e.g., removing unwanted symbols)
    
    return cleaned

# %%
# Use the above function to clean the column names
# Apply the cleaning function to all column names
df.columns = [clean(col) for col in df.columns]

# %%
# Check to ensure the column names were cleaned
df.columns
# Out:
# Index(['linename', 'c_a', 'unit', 'scp', 'station', 'division', 'date', 'time',
#        'desc', 'entries', 'exits', 'num_lines'],
#       dtype='object')

# %%
df
# Out:
#             linename    c_a  unit       scp         station division  \
# 132292  1237ACENQRSW   R151  R033  00-00-00  TIMES SQ-42 ST      IRT
# 2686    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2673    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2674    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# 2675    ACENQRS1237W   A021  R032  01-00-01  TIMES SQ-42 ST      BMT
# ...              ...    ...   ...       ...             ...      ...
# 112565             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112564             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112563             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 112562             1  PTH04  R551  00-04-05    GROVE STREET      PTH
# 197624             R  TRAM2  R469  00-05-01   RIT-ROOSEVELT      RIT
#
#               date      time     desc  entries    exits  num_lines
# 132292  08/30/2018  00:00:00  REGULAR  1417952  3267016         12
# 2686    08/29/2018  16:00:00  REGULAR  2836145  3311412         12
# 2673    08/27/2018  16:00:00  REGULAR  2830710  3305818         12
# 2674    08/27/2018  20:00:00  REGULAR  2832048  3306310         12
# 2675    08/28/2018  00:00:00  REGULAR  2832325  3306433         12
# ...            ...       ...      ...      ...      ...        ...
# 112565  08/27/2018  09:28:23  REGULAR    28975    12659          1
# 112564  08/27/2018  05:16:23  REGULAR    28319    12541          1
# 112563  08/27/2018  01:04:23  REGULAR    28318    12541          1
# 112562  08/26/2018  20:52:23  REGULAR    28305    12531          1
# 197624  08/31/2018  21:00:00  REGULAR     5554      348          1
#
# [197625 rows x 12 columns]

# %% [markdown]
# - Change the data type of the `'date'` column to a date
# - Add a new column `'day_of_week'` that represents the day of the week

# %%
# Convert the data type of the 'date' column to a date
df['date'] = pd.to_datetime(df['date'])

# Add a new column 'day_of_week' that represents the day of the week 

df['day_of_week'] = df['date'].dt.day_name()

# Check the DataFrame
df[['date', 'day_of_week']].head()
# Out:
#              date day_of_week
# 132292 2018-08-30    Thursday
# 2686   2018-08-29   Wednesday
# 2673   2018-08-27      Monday
# 2674   2018-08-27      Monday
# 2675   2018-08-28     Tuesday

# %%
# Group the data by day of week and plot the sum of the numeric columns
grouped = df.groupby('day_of_week').sum(numeric_only = True)
grouped.plot(kind='barh')
plt.show()

# %% [markdown]
# - Remove the index of `grouped`
# - Print the first five rows of `grouped`

# %%
# Reset the index of grouped
# grouped = None

# Print the first five rows of grouped
# Remove the index of grouped
grouped = grouped.reset_index()

# Print the first five rows of grouped
print(grouped.head())
# Out:
#   day_of_week        entries         exits  num_lines
# 0      Friday  1110224700078  906799065337      75573
# 1      Monday  1114237052454  911938153513      76110
# 2    Saturday  1115661545514  909142081474      74725
# 3      Sunday  1192306179082  959223750461      75306
# 4    Thursday  1122723988662  920691927110      76607

# %% [markdown]
# Add a new column `'is_weekend'` that maps the `'day_of_week'` column using the dictionary `weekend_map`

# %%
# Use this dictionary to create a new column 
weekend_map = {'Monday': False,
    'Tuesday': False,
    'Wednesday': False,
    'Thursday': False,
    'Friday': False,
    'Saturday': True,
    'Sunday': True}

# Add a new column 'is_weekend' that maps the 'day_of_week' column using weekend_map
grouped['is_weekend'] = grouped['day_of_week'].map(weekend_map)

# %%
grouped
# Out:
#   day_of_week        entries         exits  num_lines  is_weekend
# 0      Friday  1110224700078  906799065337      75573       False
# 1      Monday  1114237052454  911938153513      76110       False
# 2    Saturday  1115661545514  909142081474      74725        True
# 3      Sunday  1192306179082  959223750461      75306        True
# 4    Thursday  1122723988662  920691927110      76607       False
# 5     Tuesday  1143313287046  942230721477      77303       False
# 6   Wednesday  1123655222441  920630864687      75713       False

# %%
# Group the data by weekend/weekday and plot the sum of the numeric columns
wkend = grouped.groupby('is_weekend').sum(numeric_only = True)
wkend[['entries', 'exits']].plot(kind='barh')
plt.show()

# %% [markdown]
# Remove the `'c/a'` and `'scp'` columns.

# %%
# Remove the 'c/a' and 'scp' columns
# df = None
# df.head(2)

# %%
df=df.drop

# %% [markdown]
# ## Analysis Question
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here

# %% [markdown]
# ## Summary
#
# You practiced your data cleanup skills using Pandas.
